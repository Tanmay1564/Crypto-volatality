# %% [markdown]
# # Feature Engineering Notebook

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    Unnamed: 0        open        high         low       close  volume  \
# 0           0  112.900002  118.800003  107.142998  115.910004     0.0
# 1           1    3.493130    3.692460    3.346060    3.590890     0.0
# 2           2  115.980003  124.663002  106.639999  112.300003     0.0
# 3           3    3.594220    3.781020    3.116020    3.371250     0.0
# 4           4  112.250000  113.444000   97.699997  111.500000     0.0
#
#       marketCap                 timestamp crypto_name        date
# 0  1.288693e+09  2013-05-05T23:59:59.999Z     Bitcoin  2013-05-05
# 1  6.229819e+07  2013-05-05T23:59:59.999Z    Litecoin  2013-05-05
# 2  1.249023e+09  2013-05-06T23:59:59.999Z     Bitcoin  2013-05-06
# 3  5.859436e+07  2013-05-06T23:59:59.999Z    Litecoin  2013-05-06
# 4  1.240594e+09  2013-05-07T23:59:59.999Z     Bitcoin  2013-05-07

# %% [markdown]
# ## Missing Value Summary

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# open           0
# high           0
# low            0
# close          0
# volume         0
# marketCap      0
# timestamp      0
# crypto_name    0
# date           0
# dtype: int64

# %% [markdown]
# ## Impute Numeric Missing Values (Median)

# %%
numeric = df.select_dtypes(include=['number']).columns
df[numeric] = df[numeric].fillna(df[numeric].median())

# %% [markdown]
# ## Impute Categorical Missing Values (Mode)

# %%
categorical = df.select_dtypes(include=['object']).columns
for c in categorical: df[c] = df[c].fillna(df[c].mode()[0])

# %% [markdown]
# ## Label Encoding Categorical Columns

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\tanma\appdata\roaming\python\python312\site-packages (from scikit-learn) (2.3.5)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 560.1 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/8.0 MB 730.2 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.0/8.0 MB 883.6 kB/s eta 0:00:08
#    ------ --------------------------------- 1.3/8.0 MB 932.1 kB/s eta 0:00:08
#    ------- -------------------------------- 1.6/8.0 MB 964.5 kB/s eta 0:00:07
#    --------- ------------------------------ 1.8/8.0 MB 987.4 kB/s eta 0:00:07
#    ---------- ----------------------------- 2.1/8.0 MB 1.0 MB/s eta 0:00:06
#    ------------- -------------------------- 2.6/8.0 MB 1.2 MB/s eta 0:00:05
#    --------------- ------------------------ 3.1/8.0 MB 1.3 MB/s eta 0:00:04
#    ------------------ --------------------- 3.7/8.0 MB 1.4 MB/s eta 0:00:04
#    -------------------- ------------------- 4.2/8.0 MB 1.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.7/8.0 MB 1.5 MB/s eta 0:00:03
#    -------------------------- ------------- 5.2/8.0 MB 1.6 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.0 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 6.0/8.0 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.0 MB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 1.7 MB/s eta 0:00:00
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.3-cp312-cp312-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.6 MB ? eta -:--:--
#     --------------------------------------- 0.8/38.6 MB 1.5 MB/s eta 0:00:25
#    - -------------------------------------- 1.0/38.6 MB 1.4 MB/s eta 0:00:27
#    - -------------------------------------- 1.0/38.6 MB 1.4 MB/s eta 0:00:27
#    - -------------------------------------- 1.6/38.6 MB 1.4 MB/s eta 0:00:28
#    - -------------------------------------- 1.8/38.6 MB 1.4 MB/s eta 0:00:27
#    -- ------------------------------------- 2.1/38.6 MB 1.4 MB/s eta 0:00:26
#    -- ------------------------------------- 2.4/38.6 MB 1.4 MB/s eta 0:00:26
#    -- ------------------------------------- 2.9/38.6 MB 1.5 MB/s eta 0:00:25
#    --- ------------------------------------ 3.1/38.6 MB 1.4 MB/s eta 0:00:25
#    --- ------------------------------------ 3.7/38.6 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 3.9/38.6 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 4.2/38.6 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 4.5/38.6 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 4.7/38.6 MB 1.5 MB/s eta 0:00:23
#    ----- ---------------------------------- 5.0/38.6 MB 1.5 MB/s eta 0:00:23
#    ----- ---------------------------------- 5.2/38.6 MB 1.5 MB/s eta 0:00:23
#    ----- ---------------------------------- 5.5/38.6 MB 1.5 MB/s eta 0:00:23
#    ------ --------------------------------- 6.0/38.6 MB 1.5 MB/s eta 0:00:22
#    ------ --------------------------------- 6.3/38.6 MB 1.5 MB/s eta 0:00:22
#    ------- -------------------------------- 6.8/38.6 MB 1.5 MB/s eta 0:00:21
#    ------- -------------------------------- 7.1/38.6 MB 1.5 MB/s eta 0:00:21
#    ------- -------------------------------- 7.3/38.6 MB 1.5 MB/s eta 0:00:21
#    -------- ------------------------------- 7.9/38.6 MB 1.5 MB/s eta 0:00:20
#    -------- ------------------------------- 8.4/38.6 MB 1.6 MB/s eta 0:00:20
#    --------- ------------------------------ 8.9/38.6 MB 1.6 MB/s eta 0:00:19
#    --------- ------------------------------ 9.4/38.6 MB 1.6 MB/s eta 0:00:18
#    ---------- ----------------------------- 10.0/38.6 MB 1.7 MB/s eta 0:00:18
#    ---------- ----------------------------- 10.2/38.6 MB 1.7 MB/s eta 0:00:17
#    ----------- ---------------------------- 10.7/38.6 MB 1.7 MB/s eta 0:00:17
#    ----------- ---------------------------- 11.3/38.6 MB 1.7 MB/s eta 0:00:16
#    ----------- ---------------------------- 11.5/38.6 MB 1.7 MB/s eta 0:00:16
#    ------------ --------------------------- 12.1/38.6 MB 1.7 MB/s eta 0:00:16
#    ------------- -------------------------- 12.6/38.6 MB 1.7 MB/s eta 0:00:15
#    ------------- -------------------------- 12.8/38.6 MB 1.8 MB/s eta 0:00:15
#    ------------- -------------------------- 13.4/38.6 MB 1.8 MB/s eta 0:00:15
#    -------------- ------------------------- 13.9/38.6 MB 1.8 MB/s eta 0:00:14
#    -------------- ------------------------- 14.4/38.6 MB 1.8 MB/s eta 0:00:14
#    --------------- ------------------------ 14.7/38.6 MB 1.8 MB/s eta 0:00:14
#    --------------- ------------------------ 15.2/38.6 MB 1.8 MB/s eta 0:00:13
#    ---------------- ----------------------- 15.7/38.6 MB 1.8 MB/s eta 0:00:13
#    ---------------- ----------------------- 16.3/38.6 MB 1.8 MB/s eta 0:00:13
#    ----------------- ---------------------- 16.5/38.6 MB 1.8 MB/s eta 0:00:12
#    ----------------- ---------------------- 17.0/38.6 MB 1.8 MB/s eta 0:00:12
#    ----------------- ---------------------- 17.3/38.6 MB 1.8 MB/s eta 0:00:12
#    ------------------ --------------------- 17.8/38.6 MB 1.9 MB/s eta 0:00:12
#    ------------------- -------------------- 18.4/38.6 MB 1.9 MB/s eta 0:00:11
#    ------------------- -------------------- 18.9/38.6 MB 1.9 MB/s eta 0:00:11
#    -------------------- ------------------- 19.4/38.6 MB 1.9 MB/s eta 0:00:11
#    -------------------- ------------------- 19.9/38.6 MB 1.9 MB/s eta 0:00:10
#    -------------------- ------------------- 20.2/38.6 MB 1.9 MB/s eta 0:00:10
#    --------------------- ------------------ 20.7/38.6 MB 1.9 MB/s eta 0:00:10
#    ---------------------- ----------------- 21.2/38.6 MB 1.9 MB/s eta 0:00:10
#    ---------------------- ----------------- 21.5/38.6 MB 1.9 MB/s eta 0:00:09
#    ---------------------- ----------------- 22.0/38.6 MB 1.9 MB/s eta 0:00:09
#    ----------------------- ---------------- 22.5/38.6 MB 1.9 MB/s eta 0:00:09
#    ----------------------- ---------------- 23.1/38.6 MB 1.9 MB/s eta 0:00:09
#    ------------------------ --------------- 23.3/38.6 MB 1.9 MB/s eta 0:00:08
#    ------------------------ --------------- 23.9/38.6 MB 1.9 MB/s eta 0:00:08
#    ------------------------- -------------- 24.4/38.6 MB 1.9 MB/s eta 0:00:08
#    ------------------------- -------------- 24.9/38.6 MB 2.0 MB/s eta 0:00:07
#    -------------------------- ------------- 25.4/38.6 MB 2.0 MB/s eta 0:00:07
#    -------------------------- ------------- 26.0/38.6 MB 2.0 MB/s eta 0:00:07
#    --------------------------- ------------ 26.5/38.6 MB 2.0 MB/s eta 0:00:07
#    ---------------------------- ----------- 27.0/38.6 MB 2.0 MB/s eta 0:00:06
#    ---------------------------- ----------- 27.5/38.6 MB 2.0 MB/s eta 0:00:06
#    ----------------------------- ---------- 28.0/38.6 MB 2.0 MB/s eta 0:00:06
#    ----------------------------- ---------- 28.6/38.6 MB 2.0 MB/s eta 0:00:05
#    ------------------------------ --------- 29.1/38.6 MB 2.0 MB/s eta 0:00:05
#    ------------------------------ --------- 29.6/38.6 MB 2.0 MB/s eta 0:00:05
#    ------------------------------- -------- 29.9/38.6 MB 2.0 MB/s eta 0:00:05
#    ------------------------------- -------- 30.4/38.6 MB 2.0 MB/s eta 0:00:05
#    -------------------------------- ------- 30.9/38.6 MB 2.0 MB/s eta 0:00:04
#    -------------------------------- ------- 31.5/38.6 MB 2.0 MB/s eta 0:00:04
#    --------------------------------- ------ 32.0/38.6 MB 2.0 MB/s eta 0:00:04
#    --------------------------------- ------ 32.5/38.6 MB 2.0 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.0/38.6 MB 2.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.6/38.6 MB 2.1 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.1/38.6 MB 2.1 MB/s eta 0:00:03
#    ----------------------------------- ---- 34.3/38.6 MB 2.1 MB/s eta 0:00:03
#    ------------------------------------ --- 34.9/38.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------------ --- 35.4/38.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------------ --- 35.7/38.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------------- -- 35.9/38.6 MB 2.1 MB/s eta 0:00:02
#    ------------------------------------- -- 36.4/38.6 MB 2.0 MB/s eta 0:00:02
#    -------------------------------------- - 37.0/38.6 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.6 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 2.1 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.2 scikit-learn-1.8.0 scipy-1.16.3 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for c in categorical: df[c] = le.fit_transform(df[c])

# %% [markdown]
# ## One-Hot Encoding (Optional)

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    Unnamed: 0        open        high         low       close  volume  \
# 0           0  112.900002  118.800003  107.142998  115.910004     0.0
# 1           1    3.493130    3.692460    3.346060    3.590890     0.0
# 2           2  115.980003  124.663002  106.639999  112.300003     0.0
# 3           3    3.594220    3.781020    3.116020    3.371250     0.0
# 4           4  112.250000  113.444000   97.699997  111.500000     0.0
#
#       marketCap  timestamp  crypto_name  date
# 0  1.288693e+09          0            8     0
# 1  6.229819e+07          0           30     0
# 2  1.249023e+09          1            8     1
# 3  5.859436e+07          1           30     1
# 4  1.240594e+09          2            8     2

# %% [markdown]
# ## Feature Scaling (StandardScaler)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df[df.columns] = sc.fit_transform(df[df.columns])

# %% [markdown]
# ## Handling Outliers (IQR-cap)

# %%
Q1=df.quantile(0.25); Q3=df.quantile(0.75); IQR=Q3-Q1
for col in df.select_dtypes(include='number'):
 df[col]=df[col].clip(Q1[col]-1.5*IQR[col], Q3[col]+1.5*IQR[col])

# %% [markdown]
# ## Creating Interaction Features

# %%
import itertools
num_cols=df.select_dtypes(include='number').columns
for a,b in itertools.combinations(num_cols[:5],2): df[f'{a}_x_{b}']=df[a]*df[b]

# %% [markdown]
# ## Creating Polynomial Features

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False)
poly_df = pd.DataFrame(poly.fit_transform(df.select_dtypes(include='number')))
poly_df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -1.732027 -0.153924 -0.153329 -0.154019 -0.153934 -0.229533 -0.179447
# 1 -1.731980 -0.165666 -0.165362 -0.165516 -0.165736 -0.229533 -0.195797
# 2 -1.731932 -0.153924 -0.153329 -0.154019 -0.153934 -0.229533 -0.179976
# 3 -1.731885 -0.165647 -0.165346 -0.165561 -0.165778 -0.229533 -0.195846
# 4 -1.731837 -0.153924 -0.153329 -0.154019 -0.153934 -0.229533 -0.180088
#
#         7         8         9    ...       220       221       222       223  \
# 0 -2.502156 -1.331232 -2.502156  ...  0.000561  0.000560  0.000559  0.000562
# 1 -2.502156  0.090683 -2.502156  ...  0.000754  0.000751  0.000752  0.000753
# 2 -2.502156 -1.331232 -2.502156  ...  0.000561  0.000560  0.000559  0.000562
# 3 -2.502156  0.090683 -2.502156  ...  0.000754  0.000752  0.000753  0.000754
# 4 -2.502156 -1.331232 -2.502156  ...  0.000561  0.000560  0.000559  0.000562
#
#         224       225       226       227       228       229
# 0  0.000558  0.000557  0.000560  0.000557  0.000560  0.000562
# 1  0.000749  0.000750  0.000751  0.000751  0.000752  0.000753
# 2  0.000558  0.000557  0.000560  0.000557  0.000560  0.000562
# 3  0.000749  0.000750  0.000751  0.000751  0.000752  0.000753
# 4  0.000558  0.000557  0.000560  0.000557  0.000560  0.000562
#
# [5 rows x 230 columns]

# %% [markdown]
# ## Log Transform of Skewed Columns

# %%
import numpy as np
skewed = df.skew()[df.skew()>1].index
for col in skewed: df[col] = np.log1p(df[col])

# %% [markdown]
# ## Binning Numerical Features

# %%
for col in df.select_dtypes(include='number').columns[:3]: df[f'{col}_bin']=pd.cut(df[col], bins=5, labels=False)

# %% [markdown]
# ## Feature Selection - Variance Threshold

# %%
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=0.0)
df_sel = sel.fit_transform(df)
df_sel[:5]
# Out:
# array([[-1.73202706, -0.16714571, -0.16644258, -0.16725885, -0.16715796,
#         -0.26075852, -0.19777703, -2.50215616, -1.33123165, -2.50215616,
#          0.26659998,  0.26556924,  0.26676577,  0.26661793,  0.0236009 ,
#          0.02370723,  0.02369409,  0.02361557,  0.02360249,  0.02370883,
#          0.        ,  4.        ,  4.        ],
#        [-1.73197957, -0.18112149, -0.18075733, -0.18094174, -0.18120486,
#         -0.26075852, -0.21790321, -2.50215616,  0.09068269, -2.50215616,
#          0.28693014,  0.28640382,  0.28667038,  0.28705062,  0.02739488,
#          0.02742038,  0.02745675,  0.02737008,  0.02740639,  0.02743189,
#          0.        ,  0.        ,  0.        ],
#        [-1.73193209, -0.16714571, -0.16644258, -0.16725885, -0.16715796,
#         -0.26075852, -0.19842175, -2.50215616, -1.33123165, -2.50215616,
#          0.26658536,  0.26555467,  0.26675114,  0.26660331,  0.0236009 ,
#          0.02370723,  0.02369409,  0.02361557,  0.02360249,  0.02370883,
#          0.        ,  4.        ,  4.        ],
#        [-1.7318846 , -0.18109833, -0.18073767, -0.18099601, -0.18125515,
#         -0.26075852, -0.21796461, -2.50215616,  0.09068269, -2.50215616,
#          0.28688094,  0.2863597 ,  0.28673309,  0.28710754,  0.02738897,
#          0.02742468,  0.0274605 ,  0.02737485,  0.0274106 ,  0.02744634,
#          0.        ,  0.        ,  0.        ],
#        [-1.73183711, -0.16714571, -0.16644258, -0.16725885, -0.16715796,
#         -0.26075852, -0.1985588 , -2.50215616, -1.33123165, -2.50215616,
#          0.26657074,  0.26554011,  0.26673651,  0.26658869,  0.0236009 ,
#          0.02370723,  0.02369409,  0.02361557,  0.02360249,  0.02370883,
#          0.        ,  4.        ,  4.        ]])

# %% [markdown]
# ## Feature Selection - Mutual Information

# %%
from sklearn.feature_selection import mutual_info_classif
# replace target
# mi = mutual_info_classif(df.drop('target', axis=1), df['target'])

# %% [markdown]
# ## PCA for Dimensionality Reduction

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=5)
pca_features = pca.fit_transform(df)
pca_features[:5]
# Out:
# array([[ 1.98938889, -5.82953317, -0.74287348,  1.18581596,  0.02921576],
#        [-3.17717787, -3.2188135 , -0.02963653,  1.18610527,  0.0289171 ],
#        [ 1.98940075, -5.82949293, -0.74287511,  1.18582551,  0.02927339],
#        [-3.17716036, -3.21877721, -0.02963655,  1.18611872,  0.02898893],
#        [ 1.98942011, -5.82945137, -0.74287534,  1.18584025,  0.02935327]])

# %% [markdown]
# ## Save Final Feature Matrix

# %%
df.to_csv('final_feature_engineered.csv', index=False)
df.head()
# Out:
#    Unnamed: 0      open      high       low     close    volume  marketCap  \
# 0   -1.732027 -0.167146 -0.166443 -0.167259 -0.167158 -0.260759  -0.197777
# 1   -1.731980 -0.181121 -0.180757 -0.180942 -0.181205 -0.260759  -0.217903
# 2   -1.731932 -0.167146 -0.166443 -0.167259 -0.167158 -0.260759  -0.198422
# 3   -1.731885 -0.181098 -0.180738 -0.180996 -0.181255 -0.260759  -0.217965
# 4   -1.731837 -0.167146 -0.166443 -0.167259 -0.167158 -0.260759  -0.198559
#
#    timestamp  crypto_name      date  ...  Unnamed: 0_x_close  open_x_high  \
# 0  -2.502156    -1.331232 -2.502156  ...            0.266618     0.023601
# 1  -2.502156     0.090683 -2.502156  ...            0.287051     0.027395
# 2  -2.502156    -1.331232 -2.502156  ...            0.266603     0.023601
# 3  -2.502156     0.090683 -2.502156  ...            0.287108     0.027389
# 4  -2.502156    -1.331232 -2.502156  ...            0.266589     0.023601
#
#    open_x_low  open_x_close  high_x_low  high_x_close  low_x_close  \
# 0    0.023707      0.023694    0.023616      0.023602     0.023709
# 1    0.027420      0.027457    0.027370      0.027406     0.027432
# 2    0.023707      0.023694    0.023616      0.023602     0.023709
# 3    0.027425      0.027460    0.027375      0.027411     0.027446
# 4    0.023707      0.023694    0.023616      0.023602     0.023709
#
#    Unnamed: 0_bin  open_bin  high_bin
# 0               0         4         4
# 1               0         0         0
# 2               0         4         4
# 3               0         0         0
# 4               0         4         4
#
# [5 rows x 23 columns]
